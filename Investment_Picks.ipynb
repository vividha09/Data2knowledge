# %%
import pandas as pd
df = pd.read_csv("/content/abc2.csv", encoding = "ISO-8859-1")
df.head()
# Out:
#    Sr. No.          Company  Last Price  Change  % Chg  CEPS *  EPS *      PC  \
# 0      1.0   Medplus Health       652.8    -1.3   -0.2     0.5    0.1  1450.6
# 1      2.0     Jubilant Ind       386.0     0.4    0.1     0.1    0.1  5514.3
# 2      3.0  The InvestmentÊ        86.9     2.1    2.5     0.9    0.0    93.4
# 3      4.0   Rajesh Exports       754.6   -18.5   -2.4     0.3    0.3  2601.9
# 4      5.0    Max Financial       745.8     0.6    0.1     0.4    0.3  1775.7
#
#         PE
# 0  10879.2
# 1   5514.3
# 2   4342.5
# 3   2902.1
# 4   2330.6

# %%
df2 = df.sort_values(by=['PE'], ascending = False)
df2.head()
# Out:
#    Sr. No.          Company  Last Price  Change  % Chg  CEPS *  EPS *      PC  \
# 0      1.0   Medplus Health       652.8    -1.3   -0.2     0.5    0.1  1450.6
# 1      2.0     Jubilant Ind       386.0     0.4    0.1     0.1    0.1  5514.3
# 2      3.0  The InvestmentÊ        86.9     2.1    2.5     0.9    0.0    93.4
# 3      4.0   Rajesh Exports       754.6   -18.5   -2.4     0.3    0.3  2601.9
# 4      5.0    Max Financial       745.8     0.6    0.1     0.4    0.3  1775.7
#
#         PE
# 0  10879.2
# 1   5514.3
# 2   4342.5
# 3   2902.1
# 4   2330.6

# %%
df3 = df.sort_values(by=['PC'], ascending = False)
df3.head()
# Out:
#    Sr. No.          Company  Last Price  Change  % Chg  CEPS *  EPS *      PC  \
# 1      2.0     Jubilant Ind       386.0     0.4    0.1     0.1    0.1  5514.3
# 3      4.0   Rajesh Exports       754.6   -18.5   -2.4     0.3    0.3  2601.9
# 4      5.0    Max Financial       745.8     0.6    0.1     0.4    0.3  1775.7
# 0      1.0   Medplus Health       652.8    -1.3   -0.2     0.5    0.1  1450.6
# 7      8.0  JITF Infralogis        98.2     4.7    5.0     0.1    0.1  1227.5
#
#         PE
# 1   5514.3
# 3   2902.1
# 4   2330.6
# 0  10879.2
# 7   1227.5
